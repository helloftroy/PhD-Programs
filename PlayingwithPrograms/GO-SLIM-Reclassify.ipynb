# %% [markdown]
# # Iterate through file in order to reclassify GO terms.
# Using this tutorial: https://nbviewer.jupyter.org/urls/dessimozlab.github.io/go-handbook/GO%20Tutorial%20in%20Python%20-%20Solutions.ipynb
#     We will iterate through out file

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from math import isnan
import goatools

# %% [markdown]
# # Import data

# %%
data = pd.read_excel(r'/Users/hellpark/Desktop/Bioinformatics/model_objects/GO-SLIM/Copy of CurrentGOterms(1).xlsx',
                  skiprows = 2)
df = pd.DataFrame(data, columns=['GO Access','Function',
                                'Gene Num.','Category', 'Genes'])

# %%
df[0:3]
# Out:
#     GO Access                        Function  Gene Num.    Category  \
# 0  GO:0055085         transmembrane transport        125  metabolism
# 1  GO:0006865            amino acid transport         61  metabolism
# 2  GO:0005975  carbohydrate metabolic process        149  metabolism
#
#                                                Genes
# 0  TD01GL000101|TD01GL000142|TD01GL000261|TD01GL0...
# 1  TD01GL000165|TD01GL000166|TD01GL000168|TD01GL0...
# 2  TD01GL000005|TD01GL000009|TD01GL000010|TD01GL0...

# %%
data2 = pd.read_excel(r'/Users/hellpark/Desktop/Bioinformatics/model_objects/GO-SLIM/Copy of Go to Gene(1).xlsx',
                     sheet_name='Sheet3')
newdf = pd.DataFrame(data2)

# %%
newdf[0:3]
# Out:
#        header
# 0  GO:0071973
# 1  GO:0055085
# 2  GO:0051920

# %% [markdown]
# # Import the OBO parser from GOATools

# %%
from goatools import obo_parser
import wget
import os

# %% [markdown]
# Now, we can download the OBO file into the './data' folder using the following. We are going to download the go-basic.obo version of the ontology, which is guaranteed to be acyclic, which means that annotations can be propagated up the graph.

# %%
go_obo_url = 'http://www.geneontology.org/ontology/subsets/goslim_generic.obo'
data_folder = os.getcwd() + '/data'

# %%
# Check if we have the ./data directory already
if(not os.path.isfile(data_folder)):
    # Emulate mkdir -p (no error if folder exists)
    try:
        os.mkdir(data_folder)
    except OSError as e:
        if(e.errno != 17):
            raise e
else:
    raise Exception('Data path (' + data_folder + ') exists as a file. '
                   'Please rename, remove or change the desired location of the data path.')

# %% [markdown]
# # Check if the file exists already

# %%
if(not os.path.isfile(data_folder+'/go-basic.obo')):
    go_obo = wget.download(go_obo_url, data_folder+'/go-basic.obo')
else:
    go_obo = data_folder+'/go-basic.obo'

# %% [markdown]
# The path to the GO OBO file is now stored in the variable go_obo.

# %%
print(go_obo)
# Out:
# /Users/hellpark/Bioinformatics/data/go-basic.obo

# %% [markdown]
# Now we can create a dictionary of the GO terms, using the obo_parser from GOATools.

# %%
go = obo_parser.GODag(go_obo)
# Out:
# /Users/hellpark/Bioinformatics/data/go-basic.obo: fmt(1.2) rel(2021-08-18) 47,217 GO Terms

# %% [markdown]
# What is the name of our first missing gene, GO:0004177![image.png](attachment:image.png)

# %%
go_id = 'GO:0004177'
go_term = go[go_id]
print(go_term)
# Out:
# GO:0004177	level-05	depth-05	aminopeptidase activity [molecular_function]

# %% [markdown]
# Now recursively print all of GO:0004177 parent

# %%
def transitive_closure(go_term, go):
    go_term_set = set()
    find_parents(go_term, go, go_term_set)
    find_children(go_term, go, go_term_set)
    return go_term_set
    
def find_parents(term1, go, go_term_set={}, ret=False):
    for term2 in term1.parents:
        go_term_set.update({term2})
        
        # Recurse on term to find all parents
        find_parents(term2, go, go_term_set)          
    if(ret):
        return go_term_set

def find_children(term1, go, go_term_set={}, ret=False):
    for term2 in term1.children:
        go_term_set.update({term2})
        
        # Recurse on term to find all children
        find_children(term2, go, go_term_set)
    if(ret):
        return go_term_set

# %%
#output file
dfnew = pd.DataFrame(columns=['new gene'])

# %%
for i in newdf.index:
    go_id = newdf.at[i,'header']
    go_term = go[go_id]
    go_term_set = transitive_closure(go_term, go)
    dfadd=pd.DataFrame(go_term_set)
    dfadd['new gene'] = go_id
    dfnew=dfnew.append(dfadd)

# %%
dfnew.to_csv('/Users/hellpark/Desktop/Bioinformatics/model_objects/GO-SLIM/GO_output.csv')

# %%
dfnew=dfnew.append(dfadd)

# %%
print(dfnew)
# Out:
#      new gene                                                  0
# 0  GO:0004177  GO:0045148\tlevel-06\tdepth-06\ttripeptide ami...
# 1  GO:0004177  GO:0003674\tlevel-00\tdepth-00\tmolecular_func...
# 2  GO:0004177  GO:0070005\tlevel-06\tdepth-06\tcysteine-type ...
# 3  GO:0004177  GO:0070006\tlevel-06\tdepth-06\tmetalloaminope...
# 4  GO:0004177  GO:0008233\tlevel-03\tdepth-03\tpeptidase acti...
# 5  GO:0004177  GO:0003824\tlevel-01\tdepth-01\tcatalytic acti...
# 6  GO:0004177  GO:0070009\tlevel-06\tdepth-06\tserine-type am...
# 7  GO:0004177  GO:0140096\tlevel-02\tdepth-02\tcatalytic acti...
# 8  GO:0004177  GO:0008238\tlevel-04\tdepth-04\texopeptidase a...
# 9  GO:0004177  GO:0016787\tlevel-02\tdepth-02\thydrolase acti...

# %%
go_term_set
# Out:
# {GOTerm('GO:0003674'):
#    id:GO:0003674
#    item_id:GO:0003674
#    name:molecular_function
#    namespace:molecular_function
#    _parents: 0 items
#    parents: 0 items
#    children: 24 items
#    level:0
#    depth:0
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0005554,
#  GOTerm('GO:0003735'):
#    id:GO:0003735
#    item_id:GO:0003735
#    name:structural constituent of ribosome
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 7 items
#      GO:0003738
#      GO:0003736
#      GO:0003739
#      GO:0003737
#      GO:0003740
#      GO:0003741
#      GO:0003742,
#  GOTerm('GO:0005199'):
#    id:GO:0005199
#    item_id:GO:0005199
#    name:structural constituent of cell wall
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 1 items
#      GO:1990915	level-03	depth-03	structural constituent of ascospore wall [molecular_function]
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0005200'):
#    id:GO:0005200
#    item_id:GO:0005200
#    name:structural constituent of cytoskeleton
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 3 items
#      GO:0098699	level-03	depth-04	structural constituent of presynaptic actin cytoskeleton [molecular_function]
#      GO:0099184	level-03	depth-04	structural constituent of postsynaptic intermediate filament cytoskeleton [molecular_function]
#      GO:0098973	level-03	depth-04	structural constituent of postsynaptic actin cytoskeleton [molecular_function]
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0005201'):
#    id:GO:0005201
#    item_id:GO:0005201
#    name:extracellular matrix structural constituent
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 6 items
#      GO:0030021	level-03	depth-03	extracellular matrix structural constituent conferring compression resistance [molecular_function]
#      GO:0035804	level-03	depth-03	structural constituent of egg coat [molecular_function]
#      GO:0030020	level-03	depth-03	extracellular matrix structural constituent conferring tensile strength [molecular_function]
#      GO:0030197	level-03	depth-03	extracellular matrix constituent, lubricant activity [molecular_function]
#      GO:0030023	level-03	depth-03	extracellular matrix constituent conferring elasticity [molecular_function]
#      GO:0150043	level-03	depth-03	structural constituent of synapse-associated extracellular matrix [molecular_function]
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0005212'):
#    id:GO:0005212
#    item_id:GO:0005212
#    name:structural constituent of eye lens
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0005213'):
#    id:GO:0005213
#    item_id:GO:0005213
#    name:structural constituent of egg chorion
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0005214'):
#    id:GO:0005214
#    item_id:GO:0005214
#    name:structural constituent of chitin-based cuticle
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0042302
#    parents: 1 items
#      GO:0042302	level-02	depth-02	structural constituent of cuticle [molecular_function]
#    children: 3 items
#      GO:0008012	level-04	depth-04	structural constituent of adult chitin-based cuticle [molecular_function]
#      GO:0008010	level-04	depth-04	structural constituent of chitin-based larval cuticle [molecular_function]
#      GO:0008011	level-04	depth-04	structural constituent of pupal chitin-based cuticle [molecular_function]
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0008010'):
#    id:GO:0008010
#    item_id:GO:0008010
#    name:structural constituent of chitin-based larval cuticle
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005214
#    parents: 1 items
#      GO:0005214	level-03	depth-03	structural constituent of chitin-based cuticle [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0008011'):
#    id:GO:0008011
#    item_id:GO:0008011
#    name:structural constituent of pupal chitin-based cuticle
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005214
#    parents: 1 items
#      GO:0005214	level-03	depth-03	structural constituent of chitin-based cuticle [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0008012'):
#    id:GO:0008012
#    item_id:GO:0008012
#    name:structural constituent of adult chitin-based cuticle
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005214
#    parents: 1 items
#      GO:0005214	level-03	depth-03	structural constituent of chitin-based cuticle [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0008147'):
#    id:GO:0008147
#    item_id:GO:0008147
#    name:structural constituent of bone
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0008307'):
#    id:GO:0008307
#    item_id:GO:0008307
#    name:structural constituent of muscle
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0008316'):
#    id:GO:0008316
#    item_id:GO:0008316
#    name:structural constituent of vitelline membrane
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0016490'):
#    id:GO:0016490
#    item_id:GO:0016490
#    name:structural constituent of peritrophic membrane
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0017056'):
#    id:GO:0017056
#    item_id:GO:0017056
#    name:structural constituent of nuclear pore
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 1 items
#      GO:0005487,
#  GOTerm('GO:0019911'):
#    id:GO:0019911
#    item_id:GO:0019911
#    name:structural constituent of myelin sheath
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0030020'):
#    id:GO:0030020
#    item_id:GO:0030020
#    name:extracellular matrix structural constituent conferring tensile strength
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005201
#    parents: 1 items
#      GO:0005201	level-02	depth-02	extracellular matrix structural constituent [molecular_function]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0030021'):
#    id:GO:0030021
#    item_id:GO:0030021
#    name:extracellular matrix structural constituent conferring compression resistance
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005201
#    parents: 1 items
#      GO:0005201	level-02	depth-02	extracellular matrix structural constituent [molecular_function]
#    children: 1 items
#      GO:0030345	level-04	depth-04	structural constituent of tooth enamel [molecular_function]
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0030023'):
#    id:GO:0030023
#    item_id:GO:0030023
#    name:extracellular matrix constituent conferring elasticity
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0097493
#      GO:0005201
#    parents: 2 items
#      GO:0097493	level-02	depth-02	structural molecule activity conferring elasticity [molecular_function]
#      GO:0005201	level-02	depth-02	extracellular matrix structural constituent [molecular_function]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0030197'):
#    id:GO:0030197
#    item_id:GO:0030197
#    name:extracellular matrix constituent, lubricant activity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005201
#    parents: 1 items
#      GO:0005201	level-02	depth-02	extracellular matrix structural constituent [molecular_function]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0030280'):
#    id:GO:0030280
#    item_id:GO:0030280
#    name:structural constituent of skin epidermis
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0030281'):
#    id:GO:0030281
#    item_id:GO:0030281
#    name:structural constituent of cutaneous appendage
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0030345'):
#    id:GO:0030345
#    item_id:GO:0030345
#    name:structural constituent of tooth enamel
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0030021
#    parents: 1 items
#      GO:0030021	level-03	depth-03	extracellular matrix structural constituent conferring compression resistance [molecular_function]
#    children: 0 items
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0030527'):
#    id:GO:0030527
#    item_id:GO:0030527
#    name:structural constituent of chromatin
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0035804'):
#    id:GO:0035804
#    item_id:GO:0035804
#    name:structural constituent of egg coat
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005201
#    parents: 1 items
#      GO:0005201	level-02	depth-02	extracellular matrix structural constituent [molecular_function]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0039660'):
#    id:GO:0039660
#    item_id:GO:0039660
#    name:structural constituent of virion
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0042302'):
#    id:GO:0042302
#    item_id:GO:0042302
#    name:structural constituent of cuticle
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 2 items
#      GO:0042329	level-03	depth-03	structural constituent of collagen and cuticulin-based cuticle [molecular_function]
#      GO:0005214	level-03	depth-03	structural constituent of chitin-based cuticle [molecular_function]
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0042329'):
#    id:GO:0042329
#    item_id:GO:0042329
#    name:structural constituent of collagen and cuticulin-based cuticle
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0042302
#    parents: 1 items
#      GO:0042302	level-02	depth-02	structural constituent of cuticle [molecular_function]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0043886'):
#    id:GO:0043886
#    item_id:GO:0043886
#    name:structural constituent of carboxysome
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0097099'):
#    id:GO:0097099
#    item_id:GO:0097099
#    name:structural constituent of albumen
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 0 items
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0097493'):
#    id:GO:0097493
#    item_id:GO:0097493
#    name:structural molecule activity conferring elasticity
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 1 items
#      GO:0030023	level-03	depth-03	extracellular matrix constituent conferring elasticity [molecular_function]
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0098699'):
#    id:GO:0098699
#    item_id:GO:0098699
#    name:structural constituent of presynaptic actin cytoskeleton
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0099181
#      GO:0005200
#    parents: 2 items
#      GO:0099181	level-03	depth-03	structural constituent of presynapse [molecular_function]
#      GO:0005200	level-02	depth-02	structural constituent of cytoskeleton [molecular_function]
#    children: 0 items
#    level:3
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0098879'):
#    id:GO:0098879
#    item_id:GO:0098879
#    name:structural constituent of postsynaptic specialization
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0099186
#    parents: 1 items
#      GO:0099186	level-03	depth-03	structural constituent of postsynapse [molecular_function]
#    children: 1 items
#      GO:0098919	level-05	depth-05	structural constituent of postsynaptic density [molecular_function]
#    level:4
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0098882'):
#    id:GO:0098882
#    item_id:GO:0098882
#    name:structural constituent of presynaptic active zone
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0098918
#    parents: 1 items
#      GO:0098918	level-02	depth-02	structural constituent of synapse [molecular_function]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0098918'):
#    id:GO:0098918
#    item_id:GO:0098918
#    name:structural constituent of synapse
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005198
#    parents: 1 items
#      GO:0005198	level-01	depth-01	structural molecule activity [molecular_function]
#    children: 3 items
#      GO:0099181	level-03	depth-03	structural constituent of presynapse [molecular_function]
#      GO:0099186	level-03	depth-03	structural constituent of postsynapse [molecular_function]
#      GO:0098882	level-03	depth-03	structural constituent of presynaptic active zone [molecular_function]
#    level:2
#    depth:2
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0098919'):
#    id:GO:0098919
#    item_id:GO:0098919
#    name:structural constituent of postsynaptic density
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0098879
#    parents: 1 items
#      GO:0098879	level-04	depth-04	structural constituent of postsynaptic specialization [molecular_function]
#    children: 0 items
#    level:5
#    depth:5
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0098973'):
#    id:GO:0098973
#    item_id:GO:0098973
#    name:structural constituent of postsynaptic actin cytoskeleton
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0099186
#      GO:0005200
#    parents: 2 items
#      GO:0099186	level-03	depth-03	structural constituent of postsynapse [molecular_function]
#      GO:0005200	level-02	depth-02	structural constituent of cytoskeleton [molecular_function]
#    children: 0 items
#    level:3
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0099181'):
#    id:GO:0099181
#    item_id:GO:0099181
#    name:structural constituent of presynapse
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0098918
#    parents: 1 items
#      GO:0098918	level-02	depth-02	structural constituent of synapse [molecular_function]
#    children: 1 items
#      GO:0098699	level-03	depth-04	structural constituent of presynaptic actin cytoskeleton [molecular_function]
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0099184'):
#    id:GO:0099184
#    item_id:GO:0099184
#    name:structural constituent of postsynaptic intermediate filament cytoskeleton
#    namespace:molecular_function
#    _parents: 2 items
#      GO:0099186
#      GO:0005200
#    parents: 2 items
#      GO:0099186	level-03	depth-03	structural constituent of postsynapse [molecular_function]
#      GO:0005200	level-02	depth-02	structural constituent of cytoskeleton [molecular_function]
#    children: 0 items
#    level:3
#    depth:4
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0099186'):
#    id:GO:0099186
#    item_id:GO:0099186
#    name:structural constituent of postsynapse
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0098918
#    parents: 1 items
#      GO:0098918	level-02	depth-02	structural constituent of synapse [molecular_function]
#    children: 3 items
#      GO:0099184	level-03	depth-04	structural constituent of postsynaptic intermediate filament cytoskeleton [molecular_function]
#      GO:0098879	level-04	depth-04	structural constituent of postsynaptic specialization [molecular_function]
#      GO:0098973	level-03	depth-04	structural constituent of postsynaptic actin cytoskeleton [molecular_function]
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:0150043'):
#    id:GO:0150043
#    item_id:GO:0150043
#    name:structural constituent of synapse-associated extracellular matrix
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005201
#    parents: 1 items
#      GO:0005201	level-02	depth-02	extracellular matrix structural constituent [molecular_function]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items,
#  GOTerm('GO:1990915'):
#    id:GO:1990915
#    item_id:GO:1990915
#    name:structural constituent of ascospore wall
#    namespace:molecular_function
#    _parents: 1 items
#      GO:0005199
#    parents: 1 items
#      GO:0005199	level-02	depth-02	structural constituent of cell wall [molecular_function]
#    children: 0 items
#    level:3
#    depth:3
#    is_obsolete:False
#    alt_ids: 0 items}

# %% [markdown]
# # For GO-team reclassify paper, make all go terms in pretty format

# %%
data = pd.read_excel(r'/Users/hellpark/Desktop/Bioinformatics September 2021/model_objects/GO-SLIM/MolecularFunction_GO.xlsx',
                     sheet_name = 'MF')
df = pd.DataFrame(data)

# %%
data
# Out:
#           FastaNum                                                  1  \
# 0     TD01GL000439  {GO:0000334;3-hydroxyanthranilate 3,4-dioxygen...
# 1     TD01GL001535  {GO:0000721;(R,R)-butanediol dehydrogenase act...
# 2     TD01GL002572  {GO:0000906;6,7-dimethyl-8-ribityllumazine syn...
# 3     TD01GL003352  {GO:0000906;6,7-dimethyl-8-ribityllumazine syn...
# 4     TD01GL002234  {GO:0000988;protein binding transcription fact...
# ...            ...                                                ...
# 2251  TD01GL000927  {GO:1901505;carbohydrate derivative transporte...
# 2252  TD01GL001072  {GO:1901505;carbohydrate derivative transporte...
# 2253  TD01GL003029  {GO:1901618;organic hydroxy compound transmemb...
# 2254  TD01GL002890  {GO:1901618;organic hydroxy compound transmemb...
# 2255  TD01GL003139  {GO:1901618;organic hydroxy compound transmemb...
#
#                                                       2  \
# 0                 {GO:0005488;binding;MolecularFunction
# 1                 {GO:0005488;binding;MolecularFunction
# 2     {GO:0016867;intramolecular transferase activit...
# 3     {GO:0016867;intramolecular transferase activit...
# 4     {GO:0000989;transcription factor binding trans...
# ...                                                 ...
# 2251  {GO:0015932;nucleobase-containing compound tra...
# 2252  {GO:0016772;transferase activity, transferring...
# 2253  {GO:0008514;organic anion transmembrane transp...
# 2254  {GO:0015199;amino-acid betaine transmembrane t...
# 2255  {GO:0015199;amino-acid betaine transmembrane t...
#
#                                                       3  \
# 0     {GO:0016702;oxidoreductase activity, acting on...
# 1       {GO:0046872;metal ion binding;MolecularFunction
# 2     {GO:0016866;intramolecular transferase activit...
# 3     {GO:0016866;intramolecular transferase activit...
# 4      {GO:0003674;molecular_function;MolecularFunction
# ...                                                 ...
# 2251  {GO:0005337;nucleoside transmembrane transport...
# 2252              {GO:0005488;binding;MolecularFunction
# 2253  {GO:0008028;monocarboxylic acid transmembrane ...
# 2254  {GO:0015651;quaternary ammonium group transmem...
# 2255  {GO:0015665;alcohol transmembrane transporter ...
#
#                                                       4  \
# 0        {GO:0005506;iron ion binding;MolecularFunction
# 1     {GO:0016616;oxidoreductase activity, acting on...
# 2      {GO:0016853;isomerase activity;MolecularFunction
# 3      {GO:0016853;isomerase activity;MolecularFunction
# 4     {GO:0016989;sigma factor antagonist activity;M...
# ...                                                 ...
# 2251  {GO:0022857;transmembrane transporter activity...
# 2252  {GO:0008982;protein-N(PI)-phosphohistidine-sug...
# 2253  {GO:0005342;organic acid transmembrane transpo...
# 2254  {GO:0015101;organic cation transmembrane trans...
# 2255  {GO:0015651;quaternary ammonium group transmem...
#
#                                                       5  \
# 0     {GO:0016701;oxidoreductase activity, acting on...
# 1          {GO:0043169;cation binding;MolecularFunction
# 2      {GO:0003824;catalytic activity;MolecularFunction
# 3      {GO:0003824;catalytic activity;MolecularFunction
# 4                                                   NaN
# ...                                                 ...
# 2251  {GO:0022891;substrate-specific transmembrane t...
# 2252      {GO:0016301;kinase activity;MolecularFunction
# 2253  {GO:0046943;carboxylic acid transmembrane tran...
# 2254  {GO:0008514;organic anion transmembrane transp...
# 2255  {GO:0015101;organic cation transmembrane trans...
#
#                                                       6  \
# 0       {GO:0046872;metal ion binding;MolecularFunction
# 1        {GO:0008270;zinc ion binding;MolecularFunction
# 2      {GO:0003674;molecular_function;MolecularFunction
# 3      {GO:0003674;molecular_function;MolecularFunction
# 4                                                   NaN
# ...                                                 ...
# 2251  {GO:0005215;transporter activity;MolecularFunc...
# 2252  {GO:0022804;active transmembrane transporter a...
# 2253  {GO:0022857;transmembrane transporter activity...
# 2254  {GO:0072349;modified amino acid transmembrane ...
# 2255  {GO:0008514;organic anion transmembrane transp...
#
#                                                       7  \
# 0          {GO:0043169;cation binding;MolecularFunction
# 1     {GO:0016491;oxidoreductase activity;MolecularF...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2251  {GO:0022892;substrate-specific transporter act...
# 2252  {GO:0022857;transmembrane transporter activity...
# 2253  {GO:0022891;substrate-specific transmembrane t...
# 2254  {GO:0008028;monocarboxylic acid transmembrane ...
# 2255  {GO:0072349;modified amino acid transmembrane ...
#
#                                                       8  \
# 0     {GO:0016491;oxidoreductase activity;MolecularF...
# 1     {GO:0016614;oxidoreductase activity, acting on...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2251   {GO:0003674;molecular_function;MolecularFunction
# 2252  {GO:0022891;substrate-specific transmembrane t...
# 2253  {GO:0005215;transporter activity;MolecularFunc...
# 2254  {GO:0005342;organic acid transmembrane transpo...
# 2255  {GO:0005342;organic acid transmembrane transpo...
#
#                                                       9  ...   44   45   46  \
# 0     {GO:0051213;dioxygenase activity;MolecularFunc...  ...  NaN  NaN  NaN
# 1     {GO:0046914;transition metal ion binding;Molec...  ...  NaN  NaN  NaN
# 2                                                   NaN  ...  NaN  NaN  NaN
# 3                                                   NaN  ...  NaN  NaN  NaN
# 4                                                   NaN  ...  NaN  NaN  NaN
# ...                                                 ...  ...  ...  ...  ...
# 2251                                                NaN  ...  NaN  NaN  NaN
# 2252  {GO:0005215;transporter activity;MolecularFunc...  ...  NaN  NaN  NaN
# 2253  {GO:0022892;substrate-specific transporter act...  ...  NaN  NaN  NaN
# 2254  {GO:0046943;carboxylic acid transmembrane tran...  ...  NaN  NaN  NaN
# 2255  {GO:0046943;carboxylic acid transmembrane tran...  ...  NaN  NaN  NaN
#
#        47   48   49   50   51   52   53
# 0     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...   ...  ...  ...  ...  ...  ...  ...
# 2251  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2252  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2253  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2254  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2255  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [2256 rows x 54 columns]

# %%
df
# Out:
#           FastaNum  GO
# 0     TD01GL000001 NaN
# 1     TD01GL000002 NaN
# 2     TD01GL000003 NaN
# 3     TD01GL000004 NaN
# 4     TD01GL000005 NaN
# ...            ...  ..
# 2251  TD01GL003813 NaN
# 2252  TD01GL003814 NaN
# 2253  TD01GL003815 NaN
# 2254  TD01GL003816 NaN
# 2255  TD01GL003817 NaN
#
# [2256 rows x 2 columns]
